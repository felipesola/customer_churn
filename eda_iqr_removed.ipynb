# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Reading the dataset
df = pd.read_csv('.\datasets\customer_churn_iqr_removed.csv')
print(df.shape)
df.head(10)
# Out:
# (1631, 14)
#    Call Failure  Complaints  Subscription Length  Charge Amount  \
# 0             8           0                   38              0
# 1             0           0                   39              0
# 2            11           0                   38              1
# 3            13           0                   37              2
# 4             7           0                   38              0
# 5             7           0                   38              1
# 6             6           0                   38              0
# 7             9           0                   38              0
# 8             3           0                   37              1
# 9             0           0                   37              0
#
#    Seconds of Use  Frequency of use  Frequency of SMS  \
# 0            4370                71                 5
# 1             318                 5                 7
# 2            3775                82                32
# 3            9115               121               144
# 4           13773               169                 0
# 5            4515                83                 2
# 6            5918                95                 7
# 7            2238                54                 8
# 8            6500                86               186
# 9             875                14                 0
#
#    Distinct Called Numbers  Age Group  Tariff Plan  Status  Age  \
# 0                       17          3            1       1   30
# 1                        4          2            1       2   25
# 2                       28          3            1       1   30
# 3                       43          3            1       1   30
# 4                       44          3            1       1   30
# 5                       25          3            1       1   30
# 6                       12          3            1       1   30
# 7                       17          3            1       2   30
# 8                       26          3            1       1   30
# 9                       11          2            1       2   25
#
#    Customer Value  Churn
# 0         197.640      0
# 1          46.035      0
# 2         282.280      0
# 3         945.440      0
# 4         557.680      0
# 5         191.920      0
# 6         268.520      0
# 7         123.680      0
# 8        1007.440      0
# 9          40.005      1

# %%
# Find data types for each column
df.dtypes
# Out:
# Call Failure                 int64
# Complaints                   int64
# Subscription Length          int64
# Charge Amount                int64
# Seconds of Use               int64
# Frequency of use             int64
# Frequency of SMS             int64
# Distinct Called Numbers      int64
# Age Group                    int64
# Tariff Plan                  int64
# Status                       int64
# Age                          int64
# Customer Value             float64
# Churn                        int64
# dtype: object

# %%
## Select only columns that are numerical - 'float 64'
columns_float64 = df.select_dtypes(include=['float64', 'int64']).columns.to_list()
print(f'numerical columns: {columns_float64}')
print(f'number of numerical columns: {len(columns_float64)}')

## Select only columns that are categorical - 'object'
columns_object = df.select_dtypes(include='object').columns.to_list()
print(f'categorical columns: {columns_object}')
print(f'number of categorical columns: {len(columns_object)}')
# Out:
# numerical columns: ['Call Failure', 'Complaints', 'Subscription Length', 'Charge Amount', 'Seconds of Use', 'Frequency of use', 'Frequency of SMS', 'Distinct Called Numbers', 'Age Group', 'Tariff Plan', 'Status', 'Age', 'Customer Value', 'Churn']
# number of numerical columns: 14
# categorical columns: []
# number of categorical columns: 0

# %%
# Find and show 'isnull' data based on columns
df.isnull().sum()
# Out:
# Call Failure               0
# Complaints                 0
# Subscription Length        0
# Charge Amount              0
# Seconds of Use             0
# Frequency of use           0
# Frequency of SMS           0
# Distinct Called Numbers    0
# Age Group                  0
# Tariff Plan                0
# Status                     0
# Age                        0
# Customer Value             0
# Churn                      0
# dtype: int64

# %%
# See unique values of each column
df.nunique()
# Out:
# Call Failure                 29
# Complaints                    2
# Subscription Length          29
# Charge Amount                 3
# Seconds of Use              956
# Frequency of use            169
# Frequency of SMS            176
# Distinct Called Numbers      53
# Age Group                     2
# Tariff Plan                   2
# Status                        2
# Age                           2
# Customer Value             1334
# Churn                         2
# dtype: int64

# %%
# Find 'NaN' values on target column
data_nan = df['Churn'].value_counts(dropna = False)
display(data_nan)

# Barplot to know the 'balance' of the dataset's target
target_barplot = sns.barplot(data_nan, estimator='sum', errorbar='sd')
target_barplot.bar_label(target_barplot.containers[0], fontsize=10)
# Out:
# Churn
# 0    1289
# 1     342
# Name: count, dtype: int64
# [Text(0, 0, '1289'), Text(0, 0, '342')]

# %%
# Describe numerical statistics from the dataset 
df.describe()
# Out:
#        Call Failure   Complaints  Subscription Length  Charge Amount  \
# count   1631.000000  1631.000000          1631.000000    1631.000000
# mean       6.289393     0.089516            34.449418       0.404660
# std        5.866689     0.285574             5.499781       0.673296
# min        0.000000     0.000000            19.000000       0.000000
# 25%        1.000000     0.000000            32.000000       0.000000
# 50%        5.000000     0.000000            35.000000       0.000000
# 75%       10.000000     0.000000            38.000000       1.000000
# max       28.000000     1.000000            47.000000       2.000000
#
#        Seconds of Use  Frequency of use  Frequency of SMS  \
# count     1631.000000       1631.000000       1631.000000
# mean      3295.528510         54.461067         36.568363
# std       3064.326002         40.033523         56.229657
# min          0.000000          0.000000          0.000000
# 25%       1015.000000         24.000000          1.000000
# 50%       2585.000000         48.000000         13.000000
# 75%       4505.000000         79.500000         34.000000
# max      14078.000000        181.000000        208.000000
#
#        Distinct Called Numbers    Age Group  Tariff Plan       Status  \
# count              1631.000000  1631.000000  1631.000000  1631.000000
# mean                 18.698345     2.562845     1.040466     1.385653
# std                  12.274108     0.496187     0.197110     0.486898
# min                   0.000000     2.000000     1.000000     1.000000
# 25%                   9.000000     2.000000     1.000000     1.000000
# 50%                  17.000000     3.000000     1.000000     1.000000
# 75%                  26.000000     3.000000     1.000000     2.000000
# max                  60.000000     3.000000     2.000000     2.000000
#
#                Age  Customer Value        Churn
# count  1631.000000     1631.000000  1631.000000
# mean     27.814224      294.981048     0.209687
# std       2.480935      292.458446     0.407210
# min      25.000000        0.000000     0.000000
# 25%      25.000000       98.080000     0.000000
# 50%      30.000000      187.600000     0.000000
# 75%      30.000000      340.260000     0.000000
# max      30.000000     1099.400000     1.000000

# %%
# Describe categorical statistics from the dataset

#describe_object = df.select_dtypes(include='object')
#describe_object.describe()

# %%
# Get all numerical columns 
data_boxplot = df.select_dtypes(include=['float64', 'int64'])

# Create the subplots
fig, axs = plt.subplots(nrows=7, ncols=2, figsize=(12, 25))

# Flatten the axs array for easy iteration
axs = axs.flatten()

# Plot each column in its corresponding subplot
for i, j in enumerate(data_boxplot.columns):
    sns.boxplot(x=data_boxplot[j], ax=axs[i])

# %%
# Get all numerical columns 
data_histplot = df.select_dtypes(include=['float64', 'int64'])

# Create the subplots
fig, axs = plt.subplots(nrows=7, ncols=2, figsize=(12, 25))

# Flatten the axs array for easy iteration
axs = axs.flatten()

# Plot each column in its corresponding subplot
for i, j in enumerate(data_histplot.columns):
    sns.histplot(x=data_histplot[j], ax=axs[i])

# %%
# Make a Correlation Matrix

# Select only numerical data
data_correlation = df.select_dtypes(include=['float64', 'int64'])

# Correlation
correlation = data_correlation.corr()
correlation
# Out:
#                          Call Failure  Complaints  Subscription Length  \
# Call Failure                 1.000000    0.249646             0.101304
# Complaints                   0.249646    1.000000             0.020853
# Subscription Length          0.101304    0.020853             1.000000
# Charge Amount                0.419816   -0.137457             0.141883
# Seconds of Use               0.142079   -0.111503             0.184616
# Frequency of use             0.305676   -0.081208             0.170603
# Frequency of SMS             0.073376   -0.064414            -0.048642
# Distinct Called Numbers      0.306742   -0.020821             0.173522
# Age Group                    0.058450    0.038207             0.218391
# Tariff Plan                  0.022229    0.001002            -0.347852
# Status                      -0.004302    0.285446             0.106147
# Age                          0.058450    0.038207             0.218391
# Customer Value               0.123479   -0.102505             0.027544
# Churn                        0.155887    0.524322             0.038433
#
#                          Charge Amount  Seconds of Use  Frequency of use  \
# Call Failure                  0.419816        0.142079          0.305676
# Complaints                   -0.137457       -0.111503         -0.081208
# Subscription Length           0.141883        0.184616          0.170603
# Charge Amount                 1.000000        0.318994          0.392863
# Seconds of Use                0.318994        1.000000          0.934869
# Frequency of use              0.392863        0.934869          1.000000
# Frequency of SMS              0.357149        0.183287          0.178882
# Distinct Called Numbers       0.437110        0.768609          0.819218
# Age Group                     0.096451        0.231331          0.211923
# Tariff Plan                   0.181638       -0.060065          0.019170
# Status                       -0.476330       -0.562812         -0.585163
# Age                           0.096451        0.231331          0.211923
# Customer Value                0.426927        0.572002          0.544155
# Churn                        -0.233594       -0.267099         -0.278887
#
#                          Frequency of SMS  Distinct Called Numbers  Age Group  \
# Call Failure                     0.073376                 0.306742   0.058450
# Complaints                      -0.064414                -0.020821   0.038207
# Subscription Length             -0.048642                 0.173522   0.218391
# Charge Amount                    0.357149                 0.437110   0.096451
# Seconds of Use                   0.183287                 0.768609   0.231331
# Frequency of use                 0.178882                 0.819218   0.211923
# Frequency of SMS                 1.000000                 0.285829  -0.084014
# Distinct Called Numbers          0.285829                 1.000000   0.182623
# Age Group                       -0.084014                 0.182623   1.000000
# Tariff Plan                      0.467314                -0.021831  -0.157746
# Status                          -0.327643                -0.475118   0.002465
# Age                             -0.084014                 0.182623   1.000000
# Customer Value                   0.907581                 0.564696  -0.023580
# Churn                           -0.189922                -0.231108  -0.053114
#
#                          Tariff Plan    Status       Age  Customer Value  \
# Call Failure                0.022229 -0.004302  0.058450        0.123479
# Complaints                  0.001002  0.285446  0.038207       -0.102505
# Subscription Length        -0.347852  0.106147  0.218391        0.027544
# Charge Amount               0.181638 -0.476330  0.096451        0.426927
# Seconds of Use             -0.060065 -0.562812  0.231331        0.572002
# Frequency of use            0.019170 -0.585163  0.211923        0.544155
# Frequency of SMS            0.467314 -0.327643 -0.084014        0.907581
# Distinct Called Numbers    -0.021831 -0.475118  0.182623        0.564696
# Age Group                  -0.157746  0.002465  1.000000       -0.023580
# Tariff Plan                 1.000000 -0.162707 -0.157746        0.377603
# Status                     -0.162707  1.000000  0.002465       -0.523801
# Age                        -0.157746  0.002465  1.000000       -0.023580
# Customer Value              0.377603 -0.523801 -0.023580        1.000000
# Churn                      -0.067563  0.476844 -0.053114       -0.271771
#
#                             Churn
# Call Failure             0.155887
# Complaints               0.524322
# Subscription Length      0.038433
# Charge Amount           -0.233594
# Seconds of Use          -0.267099
# Frequency of use        -0.278887
# Frequency of SMS        -0.189922
# Distinct Called Numbers -0.231108
# Age Group               -0.053114
# Tariff Plan             -0.067563
# Status                   0.476844
# Age                     -0.053114
# Customer Value          -0.271771
# Churn                    1.000000

# %%
# Make a Correlation Heatmap

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(correlation, dtype=bool))

# Set up the matplotlib figure
fig, axs = plt.subplots(figsize=(6, 6))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlation, mask=mask, cmap='RdBu', vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >
